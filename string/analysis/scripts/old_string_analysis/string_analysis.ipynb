# %% [markdown]
# # String Simulation Analysis
#
# This notebook will help you analyse the convergence of the string-method and if you are lucky extract a nice free energy surface.

# %%
import numpy as np
import glob as glob
from math import ceil
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import MultipleLocator, FormatStrFormatter, AutoMinorLocator
from MDAnalysis.analysis.align import AlignTraj
import MDAnalysis as mda
#import nglview as nv
import pickle
import logging
import sys
import os

logging.getLogger("matplotlib").setLevel(logging.ERROR)
logging.getLogger("pyemma").setLevel(logging.NOTSET)

# %%
def colorbar(mappable, cmap, norm, label0, size=10):
    from mpl_toolkits.axes_grid1 import make_axes_locatable

    ax = mappable.axes
    fig = ax.figure
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    cbar = mpl.colorbar.ColorbarBase(cax, cmap=cmap, norm=norm)
    cbar.set_label(label0, size=size)
    return cbar

# %%
plt.rcParams["axes.facecolor"] = "#f9f9fb"
plt.rcParams["grid.color"] = "white"
plt.rcParams["grid.linestyle"] = "-"
plt.rcParams["grid.linewidth"] = 2
plt.rcParams["axes.grid"] = True
plt.rcParams["lines.solid_capstyle"] = "round"

# %%
def natural_sort(l):
    """
    Takes as input a list l of strings and sorts it with natural order.
      Parameters
      ----------
      l: list of strings.
      Returns
      -------
      l sorted
    """
    from re import split

    assert isinstance(l, list), "l is not a list!"
    for i in l:
        assert isinstance(i, str), "List contains non-string elements."
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in split("([0-9]+)", key)]
    return sorted(l, key=alphanum_key)

# %% [markdown]
# # String Convergence Analysis

# %% [markdown]
# ## Extract CVs
#
# In the cell bellow you can select which will be the simulation directory (in case this notebook is elsewhere). If the notebook is in the simulation directory just leave it as ".".

# %%
simulation_directory = "../../../string_sims/TMD_initial_path/influx_apo_gate_CV/"
os.chdir(simulation_directory)
os.getcwd()
# Out:
# '/data2/GLUT5_string/string/string_sims/TMD_initial_path/influx_apo_gate_CV'

# %% [markdown]
# Load the strings in the `strings` variable.

# %%
files = natural_sort(glob.glob("./strings/string*txt"))

# %%
strings = np.array([np.loadtxt(file).T for file in files])

# %%
with open("cv.pkl", "rb") as file:
    cvs, ndx_groups = pickle.load(file)

# %%
print("String details")
print("")
print(f"Number of string: {strings.shape[0]}")
print(f"Number of cvs: {strings.shape[1]}")
print(f"Number of beads per string: {strings.shape[2]}")
# Out:
# String details
#
# Number of string: 43
# Number of cvs: 2
# Number of beads per string: 16

# %% [markdown]
# # Analyze string convergence
# In these next plots you will be able to study the convergence of the string. At convergence the strings should be oscillating around an equilibrium position and not drift over the different iterations.
#
# ## Strings as a function of time
# In this plot we can see the evolution of each string CV as function of the timeration number separatelly.
#
# You can change two parameters in these plots the `start_iteration` before which all data is not plotted and the `n_average` which is the number of strings iterations to average in one block of strings. This is done in order to cancel some of the noisyness in the representation, to reduce the number of strings in the plot and to see more clearly if there is average drift.

# %% [markdown]
# + borrar último string
# + probar con el GPCR

# %%
start_iteration = 4
n_average = 5
fill = True

n_plots = strings.shape[1]
n_strings = strings.shape[0]
fig, ax = plt.subplots(ceil(n_plots / 2), 2, figsize=(20, 8 * ceil(n_plots / 2)))
ax = ax.flatten()
cmap = plt.cm.viridis_r
n_colors = (n_strings - start_iteration) // n_average + 1
colors = cmap(np.linspace(0, 1, n_colors))  # yellow to blue
norm = mpl.colors.Normalize(vmin=start_iteration, vmax=n_strings)

for i, a in enumerate(ax[:n_plots]):
    a.plot(strings[0, i, :], ls=":", marker=".", label="string0", color="k")
    for jj, j in enumerate(range(start_iteration, n_strings, n_average)):
        string = np.mean(strings[j : j + n_average, i, :], axis=0)
        a.plot(string, ls="-", marker="o", color=colors[jj])
    av = np.mean(strings[start_iteration:, i, :], axis=0)
    std = np.std(strings[start_iteration:, i, :], axis=0)
    if fill:
        a.fill_between(
            np.arange(len(av)),
            av + std,
            av - std,
            alpha=0.4,
            label=f"std(string{start_iteration}-{n_strings})",
        )
    a.plot(
        av,
        ls="-",
        marker=".",
        color="k",
        label=f"mean(string{start_iteration}-{n_strings})",
    )
    a.set_ylabel(
        f"{list(ndx_groups.keys())[2*i]} - {list(ndx_groups.keys())[2*i+1]} (nm)",
        size=18,
        labelpad=16,
    )
    a.set_xlabel("bead number", size=15, labelpad=13)
    a.set_xlim(left=0, right=strings.shape[2] - 1)
    a.xaxis.set_minor_locator(MultipleLocator(1))
    a.xaxis.set_major_locator(MultipleLocator(1))
    a.yaxis.set_minor_locator(MultipleLocator(0.1))
    a.yaxis.set_major_locator(MultipleLocator(0.1))
    a.grid(which="minor")
    a.tick_params(axis="y", labelsize=14)
    a.tick_params(axis="x", labelsize=11)
    if i % 2 != 0:
        a.legend()
        cbar = colorbar(a, cmap, norm, "iteration number", 20)
if n_plots % 2:
    fig.delaxes(ax[-1])

# %% [markdown]
# ## Evolution of beads with iterations
#
# In this plot the trajectory of beads cvs over iterations is presented. You can observe if the beads are stable or drifting in some direction. In this plot you can choose one parameter, `n_rolling_average`, which determines the size of the rolling average window applied to smooth-out the noisyness.

# %%
n_rolling_average = 5

n_strings = strings.shape[0]
n_cvs = strings.shape[1]
n_beads = strings.shape[2]
cmap = plt.cm.viridis_r
colors = cmap(np.linspace(0, 1, n_beads - 1))  # yellow to blue
norm = mpl.colors.Normalize(vmin=0, vmax=n_beads - 1)
fig, ax = plt.subplots(ceil(n_cvs / 2), 2, figsize=(20, 8 * ceil(n_cvs / 2)))
ax = ax.flatten()
for i in range(n_cvs):
    for j in range(1, n_beads - 1):
        y = np.convolve(
            strings[:, i, j],
            np.ones((n_rolling_average,)) / n_rolling_average,
            mode="valid",
        )
        x = np.arange(n_strings)[n_rolling_average - 1 :]
        ax[i].plot(x, y, color=colors[j])
        ax[i].set_ylabel(
            f"{list(ndx_groups.keys())[2*i]} - {list(ndx_groups.keys())[2*i+1]} (nm)",
            size=18,
            labelpad=16,
        )
        ax[i].set_xlabel("iteration number", size=15, labelpad=13)
        ax[i].yaxis.set_minor_locator(MultipleLocator(0.1))
        ax[i].yaxis.set_major_locator(MultipleLocator(0.1))
        ax[i].grid(which="minor")
        ax[i].tick_params(axis="y", labelsize=14)
        ax[i].tick_params(axis="x", labelsize=11)
    if i % 2 != 0:
        ax[i].legend()
        cbar = colorbar(ax[i], cmap, norm, "bead number", 20)
if n_plots % 2:
    fig.delaxes(ax[-1])

# %%
#Testing convolve to understand what it does
#strings: all strings,  0th CV, 1st bead 
#print(np.shape(strings[:,0,1]))
#print(np.shape(np.convolve(strings[:, 0, 1], np.ones((2)) / 2, mode = 'valid')))
#abc = [3, 10, 15, 2, 5, 10, 3, 9, 6, 13, 1, 2, 5]
#print(np.convolve(abc, np.ones((2)) / 2, mode = 'valid'))

# %% [markdown]
# ## Evolution over iterations of pairs of cvs
# In this plot you can see the evolution of the string with iterations projected onto two chosen cvs. The plots are just like in the previous section.
#
# You can choose your pair of cvs with the variables `cv_0` and `cv_1`.

# %%
print("CV numbers")
ndx_groups_list = list(ndx_groups)
for i, cv in enumerate(cvs):
    print(f"CV {i} is {ndx_groups_list[cv[0]-1]} - {ndx_groups_list[cv[1]-1]}")
# Out:
# CV numbers
# CV 0 is TM1 - TM7
# CV 1 is TM4 - TM10

# %%
if 'gate' in simulation_directory:
    cv_0 = 1   # ic gate so its on x axis
    cv_1 = 0   #ec gate so its on y axis

elif 'demyst' in simulation_directory:
    #cv_0 = 2   # 153 - 325
    #cv_1 = 12   #23- 289
    #cv_0 = 27   #112 - 292. sort of EC, but moves a lot
    #cv_1 = 29 #189-293
    #cv_0 = 16   #143 - 391 IC
    cv_0 = 19
    cv_1 = 23

# %%
start_iteration = 10
n_average = 5

errorbars = False
show_string0 = False
savefig = False

n_strings = strings.shape[0]
fig, ax = plt.subplots(1, 1, figsize=(10, 7))
cmap = plt.cm.viridis_r
n_colors = (n_strings - start_iteration) // n_average + 1
colors = cmap(np.linspace(0, 1, n_colors))  # yellow to blue
norm = mpl.colors.Normalize(vmin=start_iteration, vmax=n_strings)

### First plot the first string #### 
if show_string0:
    ax.plot(
        strings[0, cv_0, :],
        strings[0, cv_1, :],
        ls=":",
        marker=".",
        label="string0",
        color="k",
    )
    
    
### plot mean of each cv against each other (black line)
av_0 = np.mean(strings[start_iteration:, cv_0, :], axis=0)
std_0 = np.std(strings[start_iteration:, cv_0, :], axis=0)
av_1 = np.mean(strings[start_iteration:, cv_1, :], axis=0)
std_1 = np.std(strings[start_iteration:, cv_1, :], axis=0)
ax.plot(
    av_0,
    av_1,
    ls="-",
    marker=".",
    color="k",
    label=f"mean(string{start_iteration}-{n_strings})",
)


### now plot all specified iterations. Start with start iteration, end at final # strings, and skip each x for average.
### This will then take average from ex: 0-10, 10-20... etc and plot each average
for jj, j in enumerate(range(start_iteration, n_strings, n_average)):
    av_0 = np.mean(strings[j:, cv_0, :], axis=0)
    std_0 = np.std(strings[j:, cv_0, :], axis=0)
    av_1 = np.mean(strings[j:, cv_1, :], axis=0)
    std_1 = np.std(strings[j:, cv_1, :], axis=0)
    
    if errorbars:
        ax.errorbar(
            av_0, av_1, fmt="--", xerr=std_0, yerr=std_1, color=colors[jj], alpha=0.9
        )
    else:
        ax.plot(av_0, av_1, color=colors[jj], alpha =0.9)

ax.set_ylabel(
    f"{ndx_groups_list[cv_1*2]} - {ndx_groups_list[cv_1*2+1]} (nm)",
    size=18,
    labelpad=16,
)
ax.set_xlabel(
    f"{ndx_groups_list[cv_0*2]} - {ndx_groups_list[cv_0*2+1]} (nm)",
    size=18,
    labelpad=16,
)

ax.xaxis.set_minor_locator(MultipleLocator(0.1))
ax.xaxis.set_major_locator(MultipleLocator(0.1))
ax.yaxis.set_minor_locator(MultipleLocator(0.1))
ax.yaxis.set_major_locator(MultipleLocator(0.1))
ax.grid(which="minor")
ax.tick_params(axis="y", labelsize=14)
ax.tick_params(axis="x", labelsize=11)
ax.legend()
cbar = colorbar(ax, cmap, norm, "iteration number", 20)

if savefig:
    plt.savefig('images_figs/evolution_cv_pairs/evolution_CVs.%s_%s.%s_%s.png' %(ndx_groups_list[cv_0*2],
                                                      ndx_groups_list[cv_0*2+1],
                                                      ndx_groups_list[cv_1*2],
                                                      ndx_groups_list[cv_1*2+1]),
                                                      dpi = 500)

# %% [markdown]
# ## Evolution over CVs that are a function of the cvs
#
# If you are interested in studying the convergence of cvs that are a function of CVs (for example averaging over symmetrical distances). You can construct a `reduced_string` array in which cvs are a function of the cvs used for the string method. In the example bellow, we produce two cvs which are the mean of cvs used in the string method simulation. Then, similar plotting as before can be done.
#
# In addition if you are interested in the convergence of some other cv which is not a function of the cvs used in the string method you can also study them! Just extract the average value of that particular CV in the `md/*/*/restrained/traj_comp.xtc` for all the restrained simulation and shape them into an `reduced_string` numpy array with shape (n_iterations, n_cvs, n_beads).
#
# If this sort of analysis is meaningless in your system, for example because the chosen cvs are very diagnostic, please ignore this section.

# %% [markdown]
# # if this is gate CVs , skip! It will be same as above

# %%
IC = [11,15,16,19] # maybe - 2
EC = [23,22,29,27] # maybe - 12

compare_IC_EC = True

reduced_string = np.hstack(
    [
        np.mean(strings[:, IC, :], axis=1, keepdims=True),
        np.mean(strings[:, EC, :], axis=1, keepdims=True),
    ]
)
if compare_IC_EC:
    reduced_string_labels = ["IC (nm)", "EC (nm)"]
else:
    reduced_string_labels = ["X (nm)", "Y (nm)"]

# %%
np.shape(strings)
# remember strings = iterations, cvs, beads
# Out:
# (296, 30, 34)

# %%
start_iteration = 1
n_average = 80

errorbars = False
show_string0 = False
savefig = False


n_strings = strings.shape[0]
fig, ax = plt.subplots(1, 1, figsize=(10, 7))
cmap = plt.cm.viridis_r
n_colors = (n_strings - start_iteration) // n_average + 1
colors = cmap(np.linspace(0, 1, n_colors))  # yellow to blue
norm = mpl.colors.Normalize(vmin=start_iteration, vmax=n_strings)

if show_string0:
    ax.plot(
        reduced_string[0, 0, :],
        reduced_string[0, 1, :],
        ls=":",
        marker=".",
        label="string0",
        color="k",
    )
av_0 = np.mean(reduced_string[start_iteration:, 0, :], axis=0)
std_0 = np.std(reduced_string[start_iteration:, 0, :], axis=0)
av_1 = np.mean(reduced_string[start_iteration:, 1, :], axis=0)
std_1 = np.std(reduced_string[start_iteration:, 1, :], axis=0)
ax.plot(
    av_0,
    av_1,
    ls="-",
    marker=".",
    color="k",
    label=f"mean(string{start_iteration}-{n_strings})",
)

for jj, j in enumerate(range(start_iteration, n_strings, n_average)):
    av_0 = np.mean(reduced_string[j:, 0, :], axis=0)
    std_0 = np.std(reduced_string[j:, 0, :], axis=0)
    av_1 = np.mean(reduced_string[j:, 1, :], axis=0)
    std_1 = np.std(reduced_string[j:, 1, :], axis=0)
    if errorbars:
        ax.errorbar(
            av_0, av_1, fmt="--", xerr=std_0, yerr=std_1, color=colors[jj], alpha=0.9
        )
    else:
        ax.plot(
            av_0, av_1, color=colors[jj], alpha=0.9
        )   

ax.set_ylabel(
    reduced_string_labels[1], size=18, labelpad=16,
)
ax.set_xlabel(
    reduced_string_labels[0], size=18, labelpad=16,
)

ax.xaxis.set_minor_locator(MultipleLocator(0.1))
ax.xaxis.set_major_locator(MultipleLocator(0.1))
ax.yaxis.set_minor_locator(MultipleLocator(0.1))
ax.yaxis.set_major_locator(MultipleLocator(0.1))
ax.grid(which="minor")
ax.tick_params(axis="y", labelsize=14)
ax.tick_params(axis="x", labelsize=11)
ax.legend()
cbar = colorbar(ax, cmap, norm, "iteration number", 20)

if savefig:
    plt.savefig('images_figs/evolution_cv_pairs/evolution_Cvs.grouped.%s.%s.png' \
                %(reduced_string_labels[0], reduced_string_labels[1]), dpi =500)

# %% [markdown]
# ## Visualize String

# %% [markdown]
# If you have been able to install correctly [NGLview](https://github.com/nglviewer/nglview) in this jupyter-lab, which is tricky sometimes, you can visualize the `md/iter/*/restrained/confout.gro` (in ribbon, green) files. `iteration` is the iteration you want to study

# %%
iteration = 5
beads = natural_sort(glob.glob(f"md/{iteration}/*/restrained"))

# %%
traj = mda.Universe(
    beads[0] + "/confout.gro", [b + "/confout.gro" for b in beads], in_memory=True
)
start = mda.Universe("topology/start.gro")
_ = AlignTraj(traj, start, select="name CA and protein", in_memory=True).run()
# Out:
# 2021-04-27 13:43:58 MDAnalysis.core.universe-DEBUG: _process_attr: Adding <MDAnalysis.core.topologyattrs.Atomnames object at 0x7ff0474de550> to topology
# 2021-04-27 13:43:58 MDAnalysis.core.universe-DEBUG: _process_attr: Adding <MDAnalysis.core.topologyattrs.Atomids object at 0x7ff04add60d0> to topology
# 2021-04-27 13:43:58 MDAnalysis.core.universe-DEBUG: _process_attr: Adding <MDAnalysis.core.topologyattrs.Atomtypes object at 0x7ff04aab5880> to topology
# 2021-04-27 13:43:58 MDAnalysis.core.universe-DEBUG: _process_attr: Adding <MDAnalysis.core.topologyattrs.Resids object at 0x7ff0510a9d60> to topology
# 2021-04-27 13:43:58 MDAnalysis.core.universe-DEBUG: _process_attr: Adding <MDAnalysis.core.topologyattrs.Resnums object at 0x7ff04adf1be0> to topology
# 2021-04-27 13:43:58 MDAnalysis.core.universe-DEBUG: _process_attr: Adding <MDAnalysis.core.topologyattrs.Resnames object at 0x7ff04adf1af0> to topology
# 2021-04-27 13:43:58 MDAnalysis.core.universe-DEBUG: _process_attr: Adding <MDAnalysis.core.topologyattrs.Masses object at 0x7ff04adf1b20> to topology
# 2021-04-27 13:43:58 MDAnalysis.core.universe-DEBUG: _process_attr: Adding <MDAnalysis.core.topologyattrs.Segids object at 0x7ff04adcc040> to topology
# 2021-04-27 13:43:58 MDAnalysis.core.universe-DEBUG: _process_attr: Adding <MDAnalysis.core.topologyattrs.Atomindices object at 0x7ff049b7e490> to topology
# 2021-04-27 13:43:58 MDAnalysis.core.universe-DEBUG: _process_attr: Adding <MDAnalysis.core.topologyattrs.Resindices object at 0x7ff049de6130> to topology
# 2021-04-27 13:43:58 MDAnalysis.core.universe-DEBUG: _process_attr: Adding <MDAnalysis.core.topologyattrs.Segindices object at 0x7ff049de6160> to topology
# 2021-04-27 13:43:58 MDAnalysis.core.universe-DEBUG: Universe.load_new(): loading ['md/5/1/restrained/confout.gro', 'md/5/2/restrained/confout.gro', 'md/5/3/restrained/confout.gro', 'md/5/4/restrained/confout.gro', 'md/5/5/restrained/confout.gro', 'md/5/6/restrained/confout.gro', 'md/5/7/restrained/confout.gro', 'md/5/8/restrained/confout.gro', 'md/5/9/restrained/confout.gro', 'md/5/10/restrained/confout.gro', 'md/5/11/restrained/confout.gro', 'md/5/12/restrained/confout.gro', 'md/5/13/restrained/confout.gro', 'md/5/14/restrained/confout.gro', 'md/5/15/restrained/confout.gro', 'md/5/16/restrained/confout.gro', 'md/5/17/restrained/confout.gro', 'md/5/18/restrained/confout.gro', 'md/5/19/restrained/confout.gro', 'md/5/20/restrained/confout.gro', 'md/5/21/restrained/confout.gro', 'md/5/22/restrained/confout.gro', 'md/5/23/restrained/confout.gro', 'md/5/24/restrained/confout.gro', 'md/5/25/restrained/confout.gro', 'md/5/26/restrained/confout.gro', 'md/5/27/restrained/confout.gro', 'md/5/28/restrained/confout.gro', 'md/5/29/restrained/confout.gro', 'md/5/30/restrained/confout.gro', 'md/5/31/restrained/confout.gro', 'md/5/32/restrained/confout.gro']...
# /home/semccomas/anaconda3/envs/string_method/lib/python3.8/site-packages/MDAnalysis/topology/base.py:203: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   residx = np.zeros_like(criteria[0], dtype=np.int)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-146-eb1e05e5a558> in <module>
# ----> 1 traj = mda.Universe(
#       2     beads[0] + "/confout.gro", [b + "/confout.gro" for b in beads], in_memory=True
#       3 )
#       4 start = mda.Universe("topology/start.gro")
#       5 _ = AlignTraj(traj, start, select="name CA and protein", in_memory=True).run()
#
# ~/anaconda3/envs/string_method/lib/python3.8/site-packages/MDAnalysis/core/universe.py in __init__(self, *args, **kwargs)
#     389
#     390         if coordinates:
# --> 391             self.load_new(coordinates, format=format, in_memory=in_memory,
#     392                         in_memory_step=in_memory_step, **kwargs)
#     393
#
# ~/anaconda3/envs/string_method/lib/python3.8/site-packages/MDAnalysis/core/universe.py in load_new(self, filename, format, in_memory, in_memory_step, **kwargs)
#     582         kwargs['n_atoms'] = self.atoms.n_atoms
#     583
# --> 584         self.trajectory = reader(filename, format=format, **kwargs)
#     585         if self.trajectory.n_atoms != len(self.atoms):
#     586             raise ValueError("The topology and {form} trajectory files don't"
#
# ~/anaconda3/envs/string_method/lib/python3.8/site-packages/MDAnalysis/coordinates/chain.py in __init__(self, filenames, skip, dt, continuous, **kwargs)
#     262         if dt is not None:
#     263             kwargs['dt'] = dt
# --> 264         self.readers = [core.reader(filename, **kwargs)
#     265                         for filename in filenames]
#     266         self.filenames = np.array([fn[0] if isinstance(fn, tuple) else fn
#
# ~/anaconda3/envs/string_method/lib/python3.8/site-packages/MDAnalysis/coordinates/chain.py in <listcomp>(.0)
#     262         if dt is not None:
#     263             kwargs['dt'] = dt
# --> 264         self.readers = [core.reader(filename, **kwargs)
#     265                         for filename in filenames]
#     266         self.filenames = np.array([fn[0] if isinstance(fn, tuple) else fn
#
# ~/anaconda3/envs/string_method/lib/python3.8/site-packages/MDAnalysis/coordinates/core.py in reader(filename, format, **kwargs)
#      83         Reader = get_reader_for(filename, format=format)
#      84     try:
# ---> 85         return Reader(filename, **kwargs)
#      86     except ValueError:
#      87         six.raise_from(
#
# ~/anaconda3/envs/string_method/lib/python3.8/site-packages/MDAnalysis/coordinates/base.py in __init__(self, filename, convert_units, n_atoms, **kwargs)
#    2317
#    2318         self._ts_kwargs = ts_kwargs
# -> 2319         self._read_first_frame()
#    2320
#    2321     def copy(self):
#
# ~/anaconda3/envs/string_method/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py in _read_first_frame(self)
#     212                 ts._pos[pos] = [line[20 + cs * i:20 + cs * (i + 1)] for i in range(3)]
#     213                 try:
# --> 214                     velocities[pos] = [line[20 + cs * i:20 + cs * (i + 1)] for i in range(3, 6)]
#     215                 except ValueError:
#     216                     # Remember that we got this error
#
# ~/anaconda3/envs/string_method/lib/python3.8/site-packages/MDAnalysis/coordinates/GRO.py in <listcomp>(.0)
#     212                 ts._pos[pos] = [line[20 + cs * i:20 + cs * (i + 1)] for i in range(3)]
#     213                 try:
# --> 214                     velocities[pos] = [line[20 + cs * i:20 + cs * (i + 1)] for i in range(3, 6)]
#     215                 except ValueError:
#     216                     # Remember that we got this error
#
# KeyboardInterrupt:

# %%
view = nv.show_mdanalysis(traj, default=False)
view.add_ribbon(selection="protein", color="green", component=0)
view.center()

# %% [markdown]
# Sometimes need to run this cell several times to see something. Sometimes it takes a few seconds to load.

# %%
view

# %% [markdown]
# # Free Energy Surface
#
# Once your strings are converged, the swarms are sampling over and over the same part of phase space and we can discretrize it and do statistics on the jumps. This will result in a free energy surface along some cv, which may not need to be the ones that parametrize the string. It is very important to keep in mind that a converged string does not imply a converged FES and it might be necessary to do one or two (or more) hundred additional iterations.
#
#
# Now instead of using the data in `strings/string*.xtx` we will use the data in `md/*/*/s*/pullx.xvg` if we want to use the cvs of the string. Otherwise, you add here code that reads `md/*/*/s*/traj_comp.xtc`, calculates your desired cv and then shapes the data into the correct shape `(n_iterations*n_swarms_per_iter*n_beads, n_frames_per_iter, n_cvs)`.

# %% [markdown]
# The path of `sys.path.append` should lead to the library `string-method-gmxapi`

# %%
sys.path.append("../../../string-method-gmxapi/")

from stringmethod.config import *
from stringmethod.postprocessing import *
# Out:
# 2021-07-12 11:31:06 root-INFO: Setting up logging for gmxapi package.
# 2021-07-12 11:31:06 gmxapi-INFO: Importing gmxapi.
# 2021-07-12 11:31:06 gmxapi.operation-INFO: Importing gmxapi.operation
# 2021-07-12 11:31:06 gmxapi.commandline-INFO: Importing gmxapi.commandline
# 2021-07-12 11:31:06 gmxapi.simulation.workflow-INFO: Importing gmx.workflow
# 2021-07-12 11:31:06 gmxapi.simulation.workflow-INFO: Using schema version gmxapi_workspec_0_1.
# 2021-07-12 11:31:06 gmxapi.mdrun-INFO: Importing gmxapi.simulation.mdrun
# 2021-07-12 11:31:06 gmxapi.read_tpr-INFO: Importing gmxapi.simulation.read_tpr
# 2021-07-12 11:31:06 gmxapi.modify_input-INFO: Importing gmxapi.simulation.modify_input
# 2021-07-12 11:31:06 stringmethod-0-INFO: Using 1 MPI ranks

# %%
def load_swarm_data(extract, first_iteration=1, last_iteration=None):
    if last_iteration == None:
        last_iteration = sys.maxsize
    if extract:
        config = load_config("config.json")

        ce = CvValueExtractor.from_config(
            config=config,
            first_iteration=first_iteration,  # Exclude the first iterations to let the system equilibrate.
            last_iteration=last_iteration,  # Usefull to make blocks of the simulation
        )
        ce.run()
        ce.persist()
        
        os.rename("postprocessing/cv_coordinates.npy", "postprocessing/cv_coordinates.iterations.%i_%i.npy" \
                 %(first_iteration, last_iteration))
    
    
    return np.load("postprocessing/cv_coordinates.iterations.%i_%i.npy" \
                 %(first_iteration, last_iteration))

# %%
print('Iterations that have already been processed:')
print([x for x in os.listdir('%s/postprocessing' %simulation_directory[:-1]) if x.startswith("cv_coordinates")])
# Out:
# Iterations that have already been processed:
# ['cv_coordinates.iterations.200_283.npy', 'cv_coordinates.iterations.220_295.npy', 'cv_coordinates.iterations.294_295.npy', 'cv_coordinates.iterations.100_180.npy', 'cv_coordinates.iterations.295_295.npy', 'cv_coordinates.iterations.180_250.npy', 'cv_coordinates.iterations.1_90.npy', 'cv_coordinates.iterations.100_214.npy']

# %% [markdown]
# The `load_swarm_data` function will load the swarm data in the `cv_coordinates`. If you set `extract=True` it will read the data from the swarm files. If you have done this previously you can set `extract=False` so the function just reads `postprocessing/cv_coordinates.npy`. `first_iteration` can be used to exclude initial swarms as equilibration and `last_iteration` can be done to exclude some iterations for example if you want to estimate the FES convergence by comparing blocks of data.

# %%
first_iteration=220
last_iteration=295
cv_coordinates = load_swarm_data(extract=False, first_iteration=first_iteration, last_iteration=last_iteration)
print(np.shape(cv_coordinates))
# Out:
# (77824, 2, 30)

# %% [markdown]
# Since the FES that is easy to visualize can only be 1D or 2D we need to reduce the dimensionality of the CVs. For this there are several options:
# + You can choose a couple of cvs or one

# %%
#my_cvs = [8, 3]
if 'gate' in simulation_directory:
    my_cvs = [1,0]
    nameCV0 = 'IC gate'
    nameCV1 = 'EC gate'

elif 'demyst' in simulation_directory:
    #my_cvs = [19,12]  #2,12
   # my_cvs = [2,12]
  #  my_cvs = [16,29]
  #  my_cvs = [16,29]
    my_cvs = 29
   # nameCV0 = '%s_%s' % (ndx_groups_list[cvs[my_cvs[0]][0]-1], ndx_groups_list[cvs[my_cvs[0]][1]-1])
    #nameCV1 = '%s_%s' % (ndx_groups_list[cvs[my_cvs[1]][0]-1], ndx_groups_list[cvs[my_cvs[1]][1]-1])

cv_coordinates_clean = cv_coordinates[:, :, my_cvs]

print(np.shape(cv_coordinates_clean))
# Out:
# (77824, 2)

# %% [markdown]
# # Run this if you want EC or IC gate COM as CV

# %%
cv_coordinates_clean = np.load('../influx_BFRU_demyst_CV/postprocessing/gate_coordinates.npy')
print(np.shape(cv_coordinates_clean))

nameCV0 = 'IC gate'
nameCV1 = 'EC gate'
# Out:
# (139264, 2, 2)

# %% [markdown]
# + You can do some function of the cvs, like the mean of several:
# # dont need if running for gate

# %%
IC = [11,15,16,19] #2
EC = [23,22,29,27] #12
nameCV0 = 'IC_gate_group'
nameCV1 = 'EC_gate_group'

cv_coordinates_clean = np.dstack((np.mean(cv_coordinates[:,:,IC], axis = 2), 
                                      np.mean(cv_coordinates[:,:,EC], axis = 2)))

print(np.shape(cv_coordinates_clean))
# Out:
# (77824, 2, 2)

# %% [markdown]
# + You can of course make your own function that extracts cvs from the trajectory and makes a cv_coordinates_clean with the correct shape.

# %% [markdown]
# Of the above cells only run the one you are more interested in.

# %%
def calculate_transition_matrix(
    cv_coordinates, n_grid_points=20, T=303.15, kB=0.0019872041
):
    config = load_config("config.json")
    tc = TransitionCountCalculator.from_config(
        config=config,
        # You probably want to play around with n_grid_points.
        # It sets the resolution. Its optimal value depends on your swarm trajectory length and sample size
        n_grid_points=n_grid_points,
        cv_coordinates=cv_coordinates,
    )
    tc.run()
    tc.persist()
    fc = FreeEnergyCalculator.from_config(
        config=config, grid=tc.grid, transition_count=tc.transition_count
    )
    fc.run()
    fc.persist()
    return tc.grid, fc.free_energy

# %% [markdown]
# This functions takes the `cv_coordinates_clean` numpy array and calculates a transition matrix by doing a simple grid on the cv space. It also calculates the probability of transition using the master equation and this results in the calculation of a FES. `n_grid_points` choose the number of grid points of the grid, the coarse the grid the more detailed (and noisy) the FES. This parameter should be varied to obtain an acceptable signal-to-noise ration. The temperature `T` and the value of `kB` can be set too. `kB` is used to give units to the FES. In this example we will use "kBT" units since kBT=1.

# %%
grid, free_energy = calculate_transition_matrix(
    cv_coordinates_clean, n_grid_points=20, T=1, kB=1
)
# Out:
# 2021-06-08 17:42:42 stringmethod-0-WARNING: Found 121 accessible states, 279 inaccessible states and 0 states with no starting points.
# 2021-06-08 17:42:42 stringmethod-0-DEBUG: Converged with master equation after 157 iterations

# %%
def show_fes(grid, free_energy, fe_cut_off=None, cv_labels=["cv0 (nm)", "cv1 (nm)"], f_min=None, f_max=None):
    if fe_cut_off == None:
        fe_cut_off = sys.maxsize
    free_energy[free_energy > fe_cut_off] = np.nan
    cv_0 = grid[:, 0]
    fig, ax = plt.subplots(1, 1)
    if free_energy.shape[1] == 1:
        ax.plot(cv_0, free_energy, "--o")
        ax.set_ylabel("Free Energy (kT)")
    else:
        cv_1 = grid[:, 1]
        im = plt.contourf(
            cv_0,
            cv_1,
            free_energy.T,
            levels=20,
        #    norm=mpl.colors.PowerNorm(gamma=1 / 3),
            # Used to be rainbow cmap=plt.cm.rainbow
            cmap=plt.cm.RdYlGn,
            vmin=f_min,
            vmax=f_max,
        )
        cbar = plt.colorbar(im)
        cbar.set_label("Free Energy (kT)")
        ax.set_ylabel(cv_labels[1])
        ax.yaxis.set_minor_locator(MultipleLocator(0.1))
        ax.yaxis.set_major_locator(MultipleLocator(0.1))
    ax.set_xlabel(cv_labels[0])
    ax.xaxis.set_minor_locator(MultipleLocator(0.1))
    ax.xaxis.set_major_locator(MultipleLocator(0.1))
    fig.tight_layout()
    return fig, ax

# %% [markdown]
# The function bellow takes the `grid` and `free_energy` arrays from the previous step and plots the free energy surface. The function returns the matplotlib `fig` and `ax` for you to format further if you want. `fe_cut_off` is a maximum value of free energy overwhich nothing is plotted and `cv_labels` are the labels of the cvs.

# %%
fig, ax = show_fes(
    grid, free_energy, cv_labels=[nameCV0, nameCV1], fe_cut_off = None,
)

# %% [markdown]
# To save the plot.

# %%
free_energy_OL = free_energy

# %%
for x in zip(free_energy, free_energy_OL):
    print(x)
# Out:
# (array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan]), array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan]))
# (array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan]), array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan]))
# (array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan]), array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan]))
# (array([       nan,        nan,        nan,        nan,        nan,
#               nan, 4.59235847,        nan,        nan,        nan,
#        3.65049501, 4.16622664, 4.47100841, 4.38935345, 4.71996257,
#               nan,        nan,        nan,        nan,        nan]), array([       nan,        nan,        nan,        nan,        nan,
#        2.47956317, 1.64752787, 1.34940364,        nan, 1.12979239,
#        1.60574854, 2.06510827, 2.49939108,        nan, 3.62156931,
#        3.6791326 , 4.33326569,        nan,        nan,        nan]))
# (array([       nan,        nan,        nan,        nan,        nan,
#        3.39441663, 3.02388876, 2.61703069, 2.87442398, 2.97713811,
#        2.97526624, 3.13141212, 3.18741601, 3.47792454, 4.17955915,
#               nan,        nan,        nan,        nan,        nan]), array([       nan,        nan,        nan,        nan, 2.42339945,
#        2.07027162, 1.38101029, 0.8810167 , 0.65791147, 0.68709527,
#        1.17724053, 1.60672953, 1.97276801, 2.49100879, 2.71827398,
#        3.39392732, 4.49463652,        nan,        nan,        nan]))
# (array([       nan,        nan,        nan,        nan,        nan,
#        2.30318712, 2.15363144, 2.23782149, 2.59880785, 2.69318781,
#        2.65741188, 2.61404459, 2.67276756, 3.12916487, 4.0656181 ,
#               nan,        nan,        nan,        nan,        nan]), array([       nan,        nan,        nan,        nan, 2.11000215,
#        2.1212412 , 1.91696472, 0.89697307, 0.38985647, 0.92504134,
#        1.75267533, 2.16165297, 2.16800129, 2.42292252, 2.57374944,
#        3.40098432,        nan,        nan,        nan,        nan]))
# (array([       nan,        nan,        nan,        nan, 3.04237259,
#        1.73724339, 1.7972183 , 2.12111645, 2.65147072, 3.0346637 ,
#        2.83334092, 2.69717364, 2.92840294, 3.40631511, 4.345218  ,
#               nan,        nan,        nan,        nan,        nan]), array([       nan,        nan,        nan, 2.73795988, 2.21325229,
#        2.56656604,        nan,        nan, 0.52985824,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]))
# (array([       nan, 2.26814685, 2.17232012, 3.81671649, 2.33776766,
#        1.49587523, 1.58834182, 2.01252919, 2.7289536 , 3.52441301,
#        3.55067446, 3.85245898, 3.80956444,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]), array([       nan,        nan,        nan, 2.01914046, 2.40176405,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]))
# (array([       nan, 2.00324022, 1.75393187, 2.59467735, 1.51229693,
#        1.51328075, 1.86454556, 2.44126746, 3.32827067,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]), array([       nan,        nan,        nan, 1.59160743, 2.16810056,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]))
# (array([       nan, 2.26506626, 1.79372483, 2.49710678, 1.5638214 ,
#        2.15726781, 2.93995558, 3.73843664,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]), array([       nan,        nan,        nan, 1.60366857, 2.25838658,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]))
# (array([       nan, 1.16338003, 0.79343956, 2.09153607, 2.22574025,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]), array([       nan,        nan, 2.36086975, 1.99960618,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]))
# (array([       nan, 0.61675528, 0.35814395, 1.69648552,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]), array([       nan,        nan, 1.28805063, 1.2204506 ,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]))
# (array([       nan, 0.55409527, 0.22654198,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]), array([       nan,        nan, 0.72023864, 1.07787018,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]))
# (array([       nan, 0.37333606, 0.        ,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]), array([       nan,        nan, 0.39114829, 1.07588033,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]))
# (array([       nan, 0.52545356, 0.10376993, 2.21912527,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]), array([       nan,        nan, 0.69344645, 1.24691704,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]))
# (array([       nan, 0.91856547, 0.63666459,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]), array([       nan, 0.99404023, 0.67834153,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]))
# (array([4.14670548, 1.23204355, 1.34827434,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]), array([       nan, 0.19504762, 0.        ,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]))
# (array([       nan, 1.77470096, 1.76215862,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]), array([       nan, 0.29359675, 0.16659605,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]))
# (array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan]), array([       nan, 1.35477501, 1.1819086 ,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan]))
# (array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan]), array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan]))

# %%
fig.savefig(f"{simulation_directory}/free_energy.influx_demyst.iteration.%s-%s.svg" %(first_iteration, last_iteration), transparent=True)
